# %% [markdown]
# <a href="https://colab.research.google.com/github/RachapalliMounvithaLakshmi/codsoft_taskno1/blob/main/credit_card_data_set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# IMPORTING AND LOADING THE DATA SET

# %%
import pandas as pd
data=pd.read_csv('/content/credit card.csv')
data
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 0          0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1          0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2          1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3          1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4          2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...      ...       ...       ...       ...       ...       ...       ...
# 17500  28773 -0.430412  1.018080  1.560273 -0.025709 -0.061009 -0.904727
# 17501  28774 -1.184230  1.025272  1.722521 -0.246293  0.689898  1.006001
# 17502  28775  1.067437 -0.828109  0.456921  0.510196 -0.881389  0.149908
# 17503  28776 -6.392357  4.547807 -7.610294  2.051154 -3.701227 -2.361965
# 17504  28777  0.877247 -0.990305  0.565650  0.150685 -0.770408  0.625613
#
#              V7        V8        V9  ...       V21       V22       V23  \
# ...

# %% [markdown]
# CHECKING FOR THE NULL VALUES

# %%
# Check for NaN values in the entire dataset
print(data.isnull().sum())

# Check for NaN values in the target variable
print(data['Class'].isnull().sum())
# Out:
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64
# 1

# %% [markdown]
# REPLACING THE NULL VALUES

# %%
# Drop rows with NaN values
data.dropna(inplace=True)

# Verify that there are no more NaN values
print(data.isnull().sum())
# Out:
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# MODEL BUILT USING RANDOM FOREST CLASSIFIER

# %%
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report

# Normalize the 'Amount' column
scaler = StandardScaler()
data['Amount'] = scaler.fit_transform(data[['Amount']])



# Separate features and target variable
X = data.drop(columns=['Class'])
y = data['Class']

# Apply SMOTE to oversample the minority class
smote = SMOTE()
X_resampled, y_resampled = smote.fit_resample(X, y)

# Split the resampled data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

# Train the Random Forest classifier
clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train, y_train)

# Make predictions on the test set
y_pred = clf.predict(X_test)

# Evaluate the model
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
print(f'F1 Score: {f1:.2f}')

# Detailed classification report
print(classification_report(y_test, y_pred))
# Out:
# Precision: 1.00
# Recall: 1.00
# F1 Score: 1.00
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      3476
#          1.0       1.00      1.00      1.00      3494
#
#     accuracy                           1.00      6970
#    macro avg       1.00      1.00      1.00      6970
# weighted avg       1.00      1.00      1.00      6970

# %% [markdown]
# MODEL USING THE LOGISTIC REGRESSION

# %%
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report



# Check for NaN values in the dataset and remove rows with NaN values
if data.isnull().sum().sum() > 0:
    data.dropna(inplace=True)

# Normalize the 'Amount' column
scaler = StandardScaler()
data['Amount'] = scaler.fit_transform(data[['Amount']])



# Separate features and target variable
X = data.drop(columns=['Class'])
y = data['Class']

# Apply SMOTE to oversample the minority class
smote = SMOTE()
X_resampled, y_resampled = smote.fit_resample(X, y)

# Split the resampled data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

# Train the Logistic Regression classifier
clf = LogisticRegression(max_iter=1000, random_state=42)
clf.fit(X_train, y_train)

# Make predictions on the test set
y_pred = clf.predict(X_test)

# Evaluate the model
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
print(f'F1 Score: {f1:.2f}')

# Detailed classification report
print(classification_report(y_test, y_pred))
# Out:
# Precision: 0.99
# Recall: 1.00
# F1 Score: 0.99
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.99      0.99      3476
#          1.0       0.99      1.00      0.99      3494
#
#     accuracy                           0.99      6970
#    macro avg       0.99      0.99      0.99      6970
# weighted avg       0.99      0.99      0.99      6970
